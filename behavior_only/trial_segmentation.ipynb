# %% [markdown]
# # Trial segmentation and trial feature extraction
#
# In this notebook, we perform the trial segmentation for the testing sessions.
#
# The `session` object first get trial times from the `log` file present in each session directory.
# Then a list of `trial` objects are created. The trial object are extracting most of the features of the trial, using `Journeys` and `NavPath` objects when needed.
#
# Each `trial` returns a pandas DataFrame. These are concatenated by the `session` object. Finally, the `project` object concatenate the `session` DataFrames into a single DataFrame for the project.
#
# You first need to have done the position tracking analysis before doing trial segmentation and trial feature extraction.
#
# If you want to use pickle at the end, don't use importlib.reload.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os.path
import shutil
import pickle

#import importlib
#import autopipy
#importlib.reload(autopipy.project)
#importlib.reload(autopipy.session)
#importlib.reload(autopipy.navPath)
#importlib.reload(autopipy.trial)
#importlib.reload(autopipy.journey)
#importlib.reload(autopipy.lever)


from autopipy.project import Project
from autopipy.session import Session
#from autopipy.session import Session
#from autopipy.trial import Trial
#from autopipy.journey import Journey
#from autopipy.navPath import NavPath
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
projectName="autopi_behavior_2021"
dataPath="/adata/projects/autopi_behavior_2021"
dlcModelPath="/adata/models"
myProject = Project(name=projectName,dataPath=dataPath,dlcModelPath=dlcModelPath)
# Out:
# Project name: autopi_behavior_2021
# dataPath: /adata/projects/autopi_behavior_2021
# dlcModelPath: /adata/models

# %% [markdown]
# We are loading our testing sessions here

# %%
fn=myProject.dataPath+"/testing_sessions"
print("Reading " + fn)
sessionNamesTesting = pd.read_csv(fn) # this will be a pandas dataframe
myProject.createSessionList(sessionNameList=sessionNamesTesting.sessionName.to_list())
print("We have {} recording sessions".format(len(myProject.sessionList)))
# Out:
# Reading /adata/projects/autopi_behavior_2021/testing_sessions
# We have 67 recording sessions

# %% [markdown]
# ## Test segmentation on a session from our session list
#
# The `Ssession.extractTrialFeatures()` takes care extracting all trial features.

# %%
ses = myProject.sessionList[-1]
ses.extractTrialFeatures()
ses.getTrialVariablesDataFrame()
#ses.createTrialPlots()
#ses.createTrialVideos()
#ses.trialVariables.columns
#ses.trialVariables.peripheryAfterFirstLeverPressAngle
# Out:
# mn3246-05032021-1534 trial segmentation
# problem with the door alternation
# Problem with index 2647
# Removing the second of two door closings (index :2647)
# Number of trials : 91
# mn3246-05032021-1534, video len: 109687, video-log len:109687, first frame: 0, max log gap: nan, mean time diff: 0.0333, max time diff: 1.53, num problem diff: 2, frame rate: 30.0
# Lenght of mouseLeverPosi: 109687
# Lenght of videoLog: 109687
# trial feature extraction
# mn3246-05032021-1534_1, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_2, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_9, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_10, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_11, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  11008  11204
# 1  11205  11216
#              time  videoIndex
# 333  1.614955e+09       11048
# lastEnd: 11216
# trial feature extraction
# mn3246-05032021-1534_12, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_12, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_15, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_17, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_17, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  16604  16762
# 1  16763  16788
#              time  videoIndex
# 476  1.614955e+09       16654
# lastEnd: 16788
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_19, self.startTime was adjusted by -0.2 s
# There is a journey starting after the first lever press
#    start    end
# 0  18345  18471
# 1  18472  18715
# 2  18716  19190
# 3  19191  19347
# 4  19348  19372
#              time  videoIndex
# 564  1.614956e+09       19236
# lastEnd: 19372
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_25, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_27, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_28, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_29, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_30, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_31, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_31, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  34597  34772
# 1  34773  34797
#              time  videoIndex
# 870  1.614956e+09       34657
# lastEnd: 34797
# trial feature extraction
# mn3246-05032021-1534_32, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_32, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_33, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_33, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_34, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_35, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_37, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_39, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_39, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_41, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_41-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_43, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_43, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_44-8, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn3246-05032021-1534_45, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  61871  62068
# 1  62069  62093
#               time  videoIndex
# 1428  1.614957e+09       61913
# lastEnd: 62093
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_48, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_49, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_50, add a journey missed because of no brige time before first arenaCenter
# mn3246-05032021-1534_50-2, no bridge after lever press
# This situation could be caused by video synchronization problems or mouse not being visible when on the bridge
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_53, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_55, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_55, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_57, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_57, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_59, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_61, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_63, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_65, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_65, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_66, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_67, self.startTime was adjusted by -0.1 s
# trial feature extraction
# There is a journey starting after the first lever press
#    start    end
# 0  86684  87268
# 1  87269  87646
#               time  videoIndex
# 2075  1.614958e+09       86778
# 2090  1.614958e+09       87377
# 2092  1.614958e+09       87440
# lastEnd: 87646
# trial feature extraction
# mn3246-05032021-1534_69, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_69, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_70, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_73, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_76, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_78, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_78, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_79, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_81, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn3246-05032021-1534_82, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_82, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_83, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_84, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_84, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_85, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#     start     end
# 0  104816  104987
# 1  104988  105012
#               time  videoIndex
# 2489  1.614958e+09      104869
# lastEnd: 105012
# trial feature extraction
# mn3246-05032021-1534_86, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_87, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_90, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_91, self.startTime was adjusted by -0.3 s

# %%
ses.trialVariables.angularErrorHomingPeri
# Out:
# 0     4.596361
# 0     0.677459
# 0     3.134122
# 0     4.002015
# 0     0.418834
#        ...
# 0     4.169132
# 0    25.595175
# 0     5.284530
# 0     9.476000
# 0     2.744038
# Name: angularErrorHomingPeri, Length: 91, dtype: float64

# %% [markdown]
# ## Segment all the testing sessions

# %%
count = 0
for ses in myProject.sessionList:
    print("Session {}".format(count))
    ses.extractTrialFeatures() # extract every trial
    ses.getTrialVariablesDataFrame() # df is stored in the session object
    count=count+1
# Out:
# Session 0
# mn4656-30092019-2001 trial segmentation
# Remove door closing event at the beginning of the session, index 55
# problem with the door alternation
# Problem with index 1413
# Removing the second of two door closings (index :1413)
# Problem with index 1557
# Removing the second of two door closings (index :1557)
# Number of trials : 79
# mn4656-30092019-2001, video len: 108125, video-log len:108125, first frame: 0, max log gap: nan, mean time diff: 0.0337, max time diff: 0.103, num problem diff: 0, frame rate: 29.7
# Lenght of mouseLeverPosi: 108125
# Lenght of videoLog: 108125
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_18, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_26, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_32, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_34, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-30092019-2001_35-5, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-30092019-2001_36, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_38, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_40, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_42, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_44, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_46, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-30092019-2001_47, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-30092019-2001_48, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-30092019-2001_49, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-30092019-2001_50, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-30092019-2001_51, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_53, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_55, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-30092019-2001_56, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-30092019-2001_57, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-30092019-2001_58, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_60, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_62, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_68, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_70, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_72, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-30092019-2001_78, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-30092019-2001_79, self.startTime was adjusted by -0.2 s
# Session 1
# mn4656-01102019-1842 trial segmentation
# Remove door closing event at the beginning of the session, index 36
# Remove last opening of the door
# problem with the door alternation
# Problem with index 313
# Removing the second of two door closings (index :313)
# Number of trials : 74
# mn4656-01102019-1842, video len: 108646, video-log len:108646, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0376, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108646
# Lenght of videoLog: 108646
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_23, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_27, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_29, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_33, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_36-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_39-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# There is a journey starting after the first lever press
#    start    end
# 0  63712  64085
# 1  64086  64409
#               time  videoIndex
# 1049  1.569950e+09       64060
# 1051  1.569950e+09       64074
# lastEnd: 64409
# trial feature extraction
# mn4656-01102019-1842_41-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_49, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_59, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-01102019-1842_66-4, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# There is a journey starting after the first lever press
#     start     end
# 0  102094  102383
# 1  102384  103050
# 2  103051  103765
#               time  videoIndex
# 1797  1.569952e+09      102623
# 1800  1.569952e+09      103280
# lastEnd: 103765
# trial feature extraction
# mn4656-01102019-1842_71, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# Session 2
# mn4656-02102019-1702 trial segmentation
# problem with the door alternation
# Problem with index 742
# Removing the second of two door closings (index :742)
# Problem with index 871
# Removing the second of two door closings (index :871)
# Number of trials : 70
# mn4656-02102019-1702, video len: 108555, video-log len:108555, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0371, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108555
# Lenght of videoLog: 108555
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-02102019-1702_25, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-02102019-1702_26-1, homingPeriPose path has a length < 2
# mn4656-02102019-1702_26-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-02102019-1702_27-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-02102019-1702_28-2, homingPeriPose path has a length < 2
# mn4656-02102019-1702_28-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-02102019-1702_32, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# There is a journey starting after the first lever press
#    start    end
# 0  66183  66688
# 1  66689  66937
# 2  66938  67850
# 3  67851  68313
# 4  68314  69070
#               time  videoIndex
# 1212  1.570031e+09       66291
# 1215  1.570031e+09       66744
# 1217  1.570031e+09       66754
# 1219  1.570031e+09       66997
# 1221  1.570031e+09       68016
# 1223  1.570031e+09       68368
# 1225  1.570031e+09       68479
# 1227  1.570031e+09       68495
# lastEnd: 69070
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-02102019-1702_55, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-02102019-1702_70, no lever press
# mn4656-02102019-1702_70, self.valid set to False
# Session 3
# mn4656-03102019-1510 trial segmentation
# problem with the door alternation
# Problem with index 1187
# Removing the second of two door closings (index :1187)
# Problem with index 1833
# Removing the second of two door closings (index :1833)
# Number of trials : 80
# mn4656-03102019-1510, video len: 109237, video-log len:109237, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0372, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 109237
# Lenght of videoLog: 109237
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-03102019-1510_23, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-03102019-1510_27, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-03102019-1510_49, self.startTime was adjusted by -0.1 s
# mn4656-03102019-1510_49-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-03102019-1510_50, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-03102019-1510_51-4, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-03102019-1510_56, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-03102019-1510_76, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# Session 4
# mn4656-04102019-1436 trial segmentation
# problem with the door alternation
# Problem with index 1330
# Removing the second of two door closings (index :1330)
# Number of trials : 97
# mn4656-04102019-1436, video len: 108552, video-log len:108552, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0396, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108552
# Lenght of videoLog: 108552
# trial feature extraction
# mn4656-04102019-1436_1, the mouse was detected for fewer than 20 frames during the trial
# mn4656-04102019-1436_1, self.valid set to False
# mn4656-04102019-1436_1, mouse not in the lever zone when the lever was pressed
# mn4656-04102019-1436_1, self.valid set to False
# mn4656-04102019-1436_1, no time on the arenaCenter before lever press
# mn4656-04102019-1436_1, self.valid set to False
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_15, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_21, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_25, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_28, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-04102019-1436_29, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-04102019-1436_30-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_32-3, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_34, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_36, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_38-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_41, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_45, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-04102019-1436_46, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-04102019-1436_47, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_49, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_57, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_69, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-04102019-1436_70, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_72, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_74, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_81, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-04102019-1436_82, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-04102019-1436_83, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-04102019-1436_84-2, homingPeriPose path has a length < 2
# mn4656-04102019-1436_84-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-04102019-1436_85-1, homingPeriPose path has a length < 2
# mn4656-04102019-1436_85-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-04102019-1436_86, self.startTime was adjusted by -0.2 s
# mn4656-04102019-1436_86-2, homingPeriPose path has a length < 2
# mn4656-04102019-1436_86-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-04102019-1436_87, self.startTime was adjusted by -0.1 s
# mn4656-04102019-1436_87, There is no arena time after the lever press in the trial
# mn4656-04102019-1436_87, self.valid set to False
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_89, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_91, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-04102019-1436_92, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-04102019-1436_93, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-04102019-1436_97, self.startTime was adjusted by -0.2 s
# mn4656-04102019-1436_97, no lever press
# mn4656-04102019-1436_97, self.valid set to False
# mn4656-04102019-1436_97, no time in the lever zone
# mn4656-04102019-1436_97, self.valid set to False
# Session 5
# mn4656-05102019-1414 trial segmentation
# Remove door closing event at the beginning of the session, index 45
# problem with the door alternation
# Problem with index 82
# Removing the second of two door closings (index :82)
# Number of trials : 91
# mn4656-05102019-1414, video len: 108552, video-log len:108552, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0372, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108552
# Lenght of videoLog: 108552
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_11-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-05102019-1414_12, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_13, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_16-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-05102019-1414_17-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_21, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-05102019-1414_22, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_25-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-05102019-1414_26, There is no arena time after the lever press in the trial
# mn4656-05102019-1414_26, self.valid set to False
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_28, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-05102019-1414_29, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_30, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_31, self.startTime was adjusted by -0.2 s
# There is a journey starting after the first lever press
#    start    end
# 0  41135  41320
# 1  41321  41613
# 2  41614  41754
# 3  41755  42053
#              time  videoIndex
# 748  1.570279e+09       41330
# 750  1.570279e+09       41376
# 753  1.570279e+09       41630
# 755  1.570279e+09       41765
# lastEnd: 42053
# trial feature extraction
# mn4656-05102019-1414_32, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_33, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_34, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_35, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_36, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_37, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_39, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_41, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_42, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-05102019-1414_43, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_45, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_47, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-05102019-1414_48, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_50, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_51, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-05102019-1414_52, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_55, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_59, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_61, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_63, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-05102019-1414_64, self.startTime was adjusted by -0.1 s
# mn4656-05102019-1414_64-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-05102019-1414_65, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_67, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_69, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_71, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_73, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-05102019-1414_74, self.startTime was adjusted by -0.2 s
# There is a journey starting after the first lever press
#    start    end
# 0  89736  90131
# 1  90132  90604
# 2  90605  91293
# 3  91294  91689
# 4  91690  92259
#               time  videoIndex
# 1832  1.570281e+09       91376
# lastEnd: 92259
# trial feature extraction
# mn4656-05102019-1414_75, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_76, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_80, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_83, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_84, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-05102019-1414_87, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-05102019-1414_88, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-05102019-1414_89, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# Session 6
# mn4656-06102019-1429 trial segmentation
# Number of trials : 79
# mn4656-06102019-1429, video len: 108438, video-log len:108438, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0374, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108438
# Lenght of videoLog: 108438
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_10, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_12, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_14, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_16, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_19, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_24, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_26, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_28, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-06102019-1429_29, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_34, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-06102019-1429_35, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-06102019-1429_36, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_40, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_42, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_45, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-06102019-1429_46, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# There is a journey starting after the first lever press
#    start    end
# 0  62558  62797
# 1  62798  63017
# 2  63018  63263
# 3  63264  63623
# 4  63624  63810
#               time  videoIndex
# 1266  1.570367e+09       63445
# lastEnd: 63810
# trial feature extraction
# mn4656-06102019-1429_50, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_58, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-06102019-1429_59, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_63, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_65, self.startTime was adjusted by -0.1 s
# There is a journey starting after the first lever press
#    start    end
# 0  83599  84078
# 1  84079  84528
# 2  84529  84846
# 3  84847  85181
#               time  videoIndex
# 1725  1.570368e+09       84672
# lastEnd: 85181
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_73, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-06102019-1429_76, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-06102019-1429_77, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# Session 7
# mn4656-07102019-1641 trial segmentation
# Remove door closing event at the beginning of the session, index 46
# Number of trials : 78
# mn4656-07102019-1641, video len: 108547, video-log len:108547, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0689, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108547
# Lenght of videoLog: 108547
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_5-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_23, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_26, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_27, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_28, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-07102019-1641_29, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# There is a journey starting after the first lever press
#    start    end
# 0  40719  40797
# 1  40798  41173
# 2  41174  41446
# 3  41447  41811
# 4  41812  42051
# 5  42052  42224
# 6  42225  42404
# 7  42405  42530
#              time  videoIndex
# 873  1.570461e+09       42343
# 875  1.570461e+09       42365
# lastEnd: 42530
# mn4656-07102019-1641_32-7, homingPeriPose path has a length < 2
# mn4656-07102019-1641_32-7, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-07102019-1641_33, self.startTime was adjusted by -0.1 s
# mn4656-07102019-1641_33-3, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-07102019-1641_34, self.startTime was adjusted by -0.1 s
# mn4656-07102019-1641_34-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4656-07102019-1641_35-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_40, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_41, self.startTime was adjusted by -0.1 s
# mn4656-07102019-1641_41-6, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_50, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_53, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-07102019-1641_54, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_55, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-07102019-1641_56, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-07102019-1641_57, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_58, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_60, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_62, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_65, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_67, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_68, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4656-07102019-1641_69, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-07102019-1641_70, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_71, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_72, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_73, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_74, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4656-07102019-1641_75, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4656-07102019-1641_76, the mouse was detected for fewer than 20 frames during the trial
# mn4656-07102019-1641_76, self.valid set to False
# mn4656-07102019-1641_76, no lever press
# mn4656-07102019-1641_76, self.valid set to False
# mn4656-07102019-1641_76, no time in the lever zone
# mn4656-07102019-1641_76, self.valid set to False
# mn4656-07102019-1641_76, no time on the arena
# mn4656-07102019-1641_76, self.valid set to False
# trial feature extraction
# trial feature extraction
# mn4656-07102019-1641_78, self.startTime was adjusted by -0.2 s
# Session 8
# mn4672-30092019-2105 trial segmentation
# Remove door closing event at the beginning of the session, index 28
# Number of trials : 47
# mn4672-30092019-2105, video len: 68791, video-log len:68791, first frame: 0, max log gap: nan, mean time diff: 0.0337, max time diff: 1.04, num problem diff: 1, frame rate: 29.7
# Lenght of mouseLeverPosi: 68791
# Lenght of videoLog: 68791
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_2, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-30092019-2105_3, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-30092019-2105_4, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-30092019-2105_5, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-30092019-2105_6, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_8, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_10, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_12, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_14, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_16, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_18, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_20, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_22, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_24, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_26, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-30092019-2105_27, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-30092019-2105_28, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_31, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-30092019-2105_32, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# There is a journey starting after the first lever press
#    start    end
# 0  41029  41178
# 1  41179  43857
# 2  43858  45538
#              time  videoIndex
# 742  1.569872e+09       41406
# 744  1.569872e+09       41446
# 747  1.569872e+09       41849
# 749  1.569872e+09       41932
# 751  1.569872e+09       43149
# 753  1.569872e+09       43304
# 755  1.569872e+09       43319
# 757  1.569872e+09       43939
# 759  1.569872e+09       44117
# lastEnd: 45538
# trial feature extraction
# mn4672-30092019-2105_36, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_40, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-30092019-2105_41, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-30092019-2105_42, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-30092019-2105_44, self.startTime was adjusted by -0.2 s
# mn4672-30092019-2105_44-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# Session 9
# mn4672-01102019-1952 trial segmentation
# Remove door closing event at the beginning of the session, index 38
# Number of trials : 69
# mn4672-01102019-1952, video len: 108454, video-log len:108454, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0379, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108454
# Lenght of videoLog: 108454
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_6, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_8, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_10, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_13, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-01102019-1952_14-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4672-01102019-1952_15, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_17, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_19, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_20, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_21, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-01102019-1952_22, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_23, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_24, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_25, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_26, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_27, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_29, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_31, self.startTime was adjusted by -0.2 s
# There is a journey starting after the first lever press
#    start    end
# 0  44107  44529
# 1  44530  44618
# 2  44619  44648
# 3  44649  45083
# 4  45084  45093
# 5  45094  45353
# 6  45354  45482
#              time  videoIndex
# 771  1.569954e+09       45218
# 773  1.569954e+09       45225
# lastEnd: 45482
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_33, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_34, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_35, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_37, no time on the arenaCenter before lever press
# mn4672-01102019-1952_37, self.valid set to False
# trial feature extraction
# mn4672-01102019-1952_38, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_39, self.startTime was adjusted by -0.1 s
# mn4672-01102019-1952_39-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4672-01102019-1952_40, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-01102019-1952_41, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_42, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_43, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_44, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_45, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_46, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_47, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-01102019-1952_48, self.startTime was adjusted by -0.3 s
# mn4672-01102019-1952_48, no time on the arenaCenter before lever press
# mn4672-01102019-1952_48, self.valid set to False
# mn4672-01102019-1952_48, There is no arena time after the lever press in the trial
# mn4672-01102019-1952_48, self.valid set to False
# trial feature extraction
# mn4672-01102019-1952_49, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_51, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_52, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_54, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-01102019-1952_55, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_57, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_58, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_59, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_60, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-01102019-1952_61, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_63, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-01102019-1952_64, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_65, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn4672-01102019-1952_66, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-01102019-1952_68-3, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn4672-01102019-1952_69, self.startTime was adjusted by -0.2 s
# mn4672-01102019-1952_69, no lever press
# mn4672-01102019-1952_69, self.valid set to False
# Session 10
# mn4672-02102019-1809 trial segmentation
# Remove door closing event at the beginning of the session, index 45
# problem with the door alternation
# Problem with index 286
# Removing the second of two door closings (index :286)
# Problem with index 807
# Removing the second of two door closings (index :807)
# Problem with index 1689
# Removing the second of two door closings (index :1689)
# Number of trials : 62
# mn4672-02102019-1809, video len: 108465, video-log len:108465, first frame: 0, max log gap: nan, mean time diff: 0.0335, max time diff: 0.0684, num problem diff: 0, frame rate: 29.8
# Lenght of mouseLeverPosi: 108465
# Lenght of videoLog: 108465
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-02102019-1809_4-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# mn4672-02102019-1809_6, no time on the arenaCenter before lever press
# mn4672-02102019-1809_6, self.valid set to False
# trial feature extraction
# mn4672-02102019-1809_7-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-02102019-1809_15, self.startTime was adjusted by -0.6 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-02102019-1809_18, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-02102019-1809_19, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn4672-02102019-1809_24, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-02102019-1809_25, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn4672-02102019-1809_26, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn4672-02102019-1809_27, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn4672-02102019-1809_29, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# ...
# lastEnd: 38686
# mn1173-05032021-1646_29-1, homingPeriPose path has a length < 2
# mn1173-05032021-1646_29-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_30-2, no bridge after lever press
# This situation could be caused by video synchronization problems or mouse not being visible when on the bridge
# mn1173-05032021-1646_30-2, homingPeriPose path has a length < 2
# mn1173-05032021-1646_30-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_31-2, homingPeriPose path has a length < 2
# mn1173-05032021-1646_31-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_32-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_33-1, homingPeriPose path has a length < 2
# mn1173-05032021-1646_33-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_34-3, homingPeriPose path has a length < 2
# mn1173-05032021-1646_34-3, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_35, self.startTime was adjusted by -0.1 s
# mn1173-05032021-1646_35, There is no arena time after the lever press in the trial
# mn1173-05032021-1646_35, self.valid set to False
# trial feature extraction
# mn1173-05032021-1646_36-2, homingPeriPose path has a length < 2
# mn1173-05032021-1646_36-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_37-1, homingPeriPose path has a length < 2
# mn1173-05032021-1646_37-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# /home/kevin/repo/autopipy/autopipy/lever.py:127: RuntimeWarning: invalid value encountered in true_divide
#   uvLong = vLong/vLongLength # unit vector
# /home/kevin/repo/autopipy/autopipy/lever.py:127: RuntimeWarning: invalid value encountered in true_divide
#   uvLong = vLong/vLongLength # unit vector
# mn1173-05032021-1646_38-2, homingPeriPose path has a length < 2
# mn1173-05032021-1646_38-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_39, no time in the lever zone
# mn1173-05032021-1646_39, self.valid set to False
# mn1173-05032021-1646_39, mouse not in the lever zone when the lever was pressed
# mn1173-05032021-1646_39, self.valid set to False
# trial feature extraction
# mn1173-05032021-1646_40-1, homingPeriPose path has a length < 2
# mn1173-05032021-1646_40-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_41, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn1173-05032021-1646_42-2, homingPeriPose path has a length < 2
# mn1173-05032021-1646_42-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_43, self.startTime was adjusted by -0.3 s
# mn1173-05032021-1646_43-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_44-3, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_45-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_46-1, homingPeriPose path has a length < 2
# mn1173-05032021-1646_46-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_47, mouse not in the lever zone when the lever was pressed
# mn1173-05032021-1646_47, self.valid set to False
# trial feature extraction
# mn1173-05032021-1646_48-2, homingPeriPose path has a length < 2
# mn1173-05032021-1646_48-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn1173-05032021-1646_49, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_51, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_53, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn1173-05032021-1646_54, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn1173-05032021-1646_55, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_57, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn1173-05032021-1646_58, self.startTime was adjusted by -0.1 s
# mn1173-05032021-1646_58, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_64, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_67, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_69, self.startTime was adjusted by -0.2 s
# mn1173-05032021-1646_69-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_71-2, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_73, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn1173-05032021-1646_74, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn1173-05032021-1646_75, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn1173-05032021-1646_76, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn1173-05032021-1646_77, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_79, self.startTime was adjusted by -0.3 s
# mn1173-05032021-1646_79, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn1173-05032021-1646_80, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_82, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn1173-05032021-1646_83, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_86, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn1173-05032021-1646_87, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn1173-05032021-1646_88, self.startTime was adjusted by -0.1 s
# mn1173-05032021-1646_88, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn1173-05032021-1646_90, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn1173-05032021-1646_91, no lever press
# mn1173-05032021-1646_91, self.valid set to False
# Session 66
# mn3246-05032021-1534 trial segmentation
# problem with the door alternation
# Problem with index 2647
# Removing the second of two door closings (index :2647)
# Number of trials : 91
# mn3246-05032021-1534, video len: 109687, video-log len:109687, first frame: 0, max log gap: nan, mean time diff: 0.0333, max time diff: 1.53, num problem diff: 2, frame rate: 30.0
# Lenght of mouseLeverPosi: 109687
# Lenght of videoLog: 109687
# trial feature extraction
# mn3246-05032021-1534_1, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_2, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_9, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_10, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_11, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  11008  11204
# 1  11205  11216
#              time  videoIndex
# 333  1.614955e+09       11048
# lastEnd: 11216
# trial feature extraction
# mn3246-05032021-1534_12, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_12, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_15, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_17, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_17, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  16604  16762
# 1  16763  16788
#              time  videoIndex
# 476  1.614955e+09       16654
# lastEnd: 16788
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_19, self.startTime was adjusted by -0.2 s
# There is a journey starting after the first lever press
#    start    end
# 0  18345  18471
# 1  18472  18715
# 2  18716  19190
# 3  19191  19347
# 4  19348  19372
#              time  videoIndex
# 564  1.614956e+09       19236
# lastEnd: 19372
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_25, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_27, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_28, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_29, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_30, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_31, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_31, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  34597  34772
# 1  34773  34797
#              time  videoIndex
# 870  1.614956e+09       34657
# lastEnd: 34797
# trial feature extraction
# mn3246-05032021-1534_32, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_32, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_33, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_33, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_34, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_35, self.startTime was adjusted by -0.3 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_37, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_39, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_39, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_41, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_41-1, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_43, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_43, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_44-8, homingPeriNoLeverPose path has a length < 2
# trial feature extraction
# mn3246-05032021-1534_45, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#    start    end
# 0  61871  62068
# 1  62069  62093
#               time  videoIndex
# 1428  1.614957e+09       61913
# lastEnd: 62093
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_48, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_49, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_50, add a journey missed because of no brige time before first arenaCenter
# mn3246-05032021-1534_50-2, no bridge after lever press
# This situation could be caused by video synchronization problems or mouse not being visible when on the bridge
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_53, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_55, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_55, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_57, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_57, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_59, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_61, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_63, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_65, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_65, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_66, self.startTime was adjusted by -0.1 s
# trial feature extraction
# mn3246-05032021-1534_67, self.startTime was adjusted by -0.1 s
# trial feature extraction
# There is a journey starting after the first lever press
#    start    end
# 0  86684  87268
# 1  87269  87646
#               time  videoIndex
# 2075  1.614958e+09       86778
# 2090  1.614958e+09       87377
# 2092  1.614958e+09       87440
# lastEnd: 87646
# trial feature extraction
# mn3246-05032021-1534_69, self.startTime was adjusted by -0.3 s
# mn3246-05032021-1534_69, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_70, self.startTime was adjusted by -0.1 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_73, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_76, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_78, self.startTime was adjusted by -0.2 s
# mn3246-05032021-1534_78, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_79, self.startTime was adjusted by -0.2 s
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_81, self.startTime was adjusted by -0.3 s
# trial feature extraction
# mn3246-05032021-1534_82, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_82, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_83, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_84, self.startTime was adjusted by -0.1 s
# mn3246-05032021-1534_84, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# mn3246-05032021-1534_85, add a journey missed because of no brige time before first arenaCenter
# There is a journey starting after the first lever press
#     start     end
# 0  104816  104987
# 1  104988  105012
#               time  videoIndex
# 2489  1.614958e+09      104869
# lastEnd: 105012
# trial feature extraction
# mn3246-05032021-1534_86, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_87, add a journey missed because of no brige time before first arenaCenter
# trial feature extraction
# trial feature extraction
# trial feature extraction
# mn3246-05032021-1534_90, self.startTime was adjusted by -0.2 s
# trial feature extraction
# mn3246-05032021-1534_91, self.startTime was adjusted by -0.3 s

# %% [markdown]
# ## Get all trials into a single dataframe
#
# We want to save this data frame for further analysis. The project class has a function to get all the trial dataframes togeter. We then save the dataframe as a csv file.

# %%
trialsDF = myProject.getTrialVariables()
sProfile = myProject.getTrialPathSpeedProfile()

# %%
# save the DataFram as csv file
fn = myProject.dataPath+"/results/trialsDF.csv"
trialsDF.to_csv(fn)

# %%
# save the path speed profiles (dictionary of np.arrays) as a pickle file
fn = myProject.dataPath+"/results/speedProfile.pkl"
pickle.dump(sProfile,open( fn, "wb" ))

# %%
# save the project object, with the already analyzed sessions!
# 3,3 Gb of data!

fn = myProject.dataPath+"/results/myProject.pkl"
pickle.dump(myProject,open(fn,"wb"))
